# %% [markdown]
# 1. Importar as bibliotecas Pandas (pd) e math

# %%
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 2. Definir a variável "arquivo" pelo nome da planilha.

# %%
arquivo='energia sustentável 1.xlsx'

# %% [markdown]
# 3. Ler a planilha no Python. Escolha um nome para armazenar. Escolheremos df

# %%
df=pd.read_excel(arquivo)
df
# Out:
#              País  Eletricidade a partir de combustíveis fósseis (TWh)  \
# 0     Afghanistan                                               0.16
# 1     Afghanistan                                               0.09
# 2     Afghanistan                                               0.13
# 3     Afghanistan                                               0.31
# 4     Afghanistan                                               0.33
# ...           ...                                                ...
# 3623     Zimbabwe                                               3.50
# 3624     Zimbabwe                                               3.05
# 3625     Zimbabwe                                               3.73
# 3626     Zimbabwe                                               3.66
# 3627     Zimbabwe                                               3.40
#
#       Eletricidade de fontes renováveis ​​(TWh)
# 0                                          0.31
# 1                                          0.50
# 2                                          0.56
# 3                                          0.63
# 4                                          0.56
# ...                                         ...
# 3623                                       3.32
# 3624                                       4.30
# 3625                                       5.46
# 3626                                       4.58
# 3627                                       4.19
#
# [3628 rows x 3 columns]

# %% [markdown]
# 4.Agrupando os valores qualitativos a partir da variável selecionada.Escolhemos país/região (nome da coluna no arquivo df)

# %%
df2=df.País.value_counts()
df2
# Out:
# Afghanistan      21
# Norway           21
# Nepal            21
# Netherlands      21
# New Caledonia    21
#                  ..
# Zimbabwe         21
# Serbia           14
# Montenegro       14
# South Sudan       8
# French Guiana     1
# Name: País, Length: 175, dtype: int64

# %% [markdown]
# 5. Ordenando os valores da variável em ordem alfabética

# %%
df2=df.País.value_counts().sort_index()
df2
# Out:
# Afghanistan            21
# Albania                21
# Algeria                21
# Angola                 21
# Antigua and Barbuda    21
#                        ..
# Uzbekistan             21
# Vanuatu                21
# Yemen                  21
# Zambia                 21
# Zimbabwe               21
# Name: País, Length: 175, dtype: int64

# %% [markdown]
# 6. Contando o total de elementos

# %%
totaldf2=df2.sum()
totaldf2
# Out:
# 3628

# %% [markdown]
# 7. Montando a tabela de frequências da variável

# %% [markdown]
# 7.1. Criar um DataFrame para a coluna desejada (dadosvquali no exemplo)

# %%
dadosvquali=pd.DataFrame(df2)

# %%
dadosvquali
# Out:
#                      País
# Afghanistan            21
# Albania                21
# Algeria                21
# Angola                 21
# Antigua and Barbuda    21
# ...                   ...
# Uzbekistan             21
# Vanuatu                21
# Yemen                  21
# Zambia                 21
# Zimbabwe               21
#
# [175 rows x 1 columns]

# %% [markdown]
# 7.2 Calcular a frequencia relativa em % com 2 casas decimais

# %%
dadosvquali['Frequência %']=round(dadosvquali['País']*100/totaldf2,2)
dadosvquali
# Out:
#                      País  Frequência %
# Afghanistan            21          0.58
# Albania                21          0.58
# Algeria                21          0.58
# Angola                 21          0.58
# Antigua and Barbuda    21          0.58
# ...                   ...           ...
# Uzbekistan             21          0.58
# Vanuatu                21          0.58
# Yemen                  21          0.58
# Zambia                 21          0.58
# Zimbabwe               21          0.58
#
# [175 rows x 2 columns]

# %% [markdown]
# 7.3 Criando uma nova tabela, renomeando as colunas

# %%
tabela=pd.DataFrame({"País":dadosvquali.index,"Frequência":dadosvquali['País'],"Frequência %":dadosvquali["Frequência %"]})

# %%
tabela
# Out:
#                                     País  Frequência  Frequência %
# Afghanistan                  Afghanistan          21          0.58
# Albania                          Albania          21          0.58
# Algeria                          Algeria          21          0.58
# Angola                            Angola          21          0.58
# Antigua and Barbuda  Antigua and Barbuda          21          0.58
# ...                                  ...         ...           ...
# Uzbekistan                    Uzbekistan          21          0.58
# Vanuatu                          Vanuatu          21          0.58
# Yemen                              Yemen          21          0.58
# Zambia                            Zambia          21          0.58
# Zimbabwe                        Zimbabwe          21          0.58
#
# [175 rows x 3 columns]

# %% [markdown]
# 8. Moda da variável "Países".
#
# Analiza-se neste ponto qual a informação que mais se repete na tabela (possui maior frequência).

# %%
moda = df["País"].mode()
moda
# Out:
# 0              Afghanistan
# 1                  Albania
# 2                  Algeria
# 3                   Angola
# 4      Antigua and Barbuda
#               ...
# 166             Uzbekistan
# 167                Vanuatu
# 168                  Yemen
# 169                 Zambia
# 170               Zimbabwe
# Name: País, Length: 171, dtype: object

# %% [markdown]
# 9. Gráficos para variáveis qualitativas

# %%
#ajustando os eixos da figura para melhor visualização e dando nomes aos eixos
fig,ax=plt.subplots(figsize=(5,5))
sns.countplot(x='País',data=df)
ax.set_xlabel("País", size=12)
ax.set_ylabel("Frequência",size=12)
ax.set_title("Frequência do País",size=20)
plt.show()

# %%
#gráficos de variável qualitativa ordenada
df2=df.País.value_counts().sort_index()
df2
# Out:
# Afghanistan            21
# Albania                21
# Algeria                21
# Angola                 21
# Antigua and Barbuda    21
#                        ..
# Uzbekistan             21
# Vanuatu                21
# Yemen                  21
# Zambia                 21
# Zimbabwe               21
# Name: País, Length: 175, dtype: int64

# %%
#criando os rótulos e os valores baseados na ordenação anterior
rótulos2=['países com freq 21',' países com freq 14',' países com freq 8',' países com freq 1' ]
valores2=[175,2,1,1]
#criando gráfico de setor
plt.figure(figsize=(10,10))
plt.pie(valores2,labels=rótulos2,autopct='%1.1f%%',startangle=90)
plt.legend()
plt.show()

# %%
#gráfico de barra, também usando os rótulos e valores
plt.bar(rótulos2,valores2)
plt.xlabel('País',fontsize=15)
plt.ylabel('Quantidade de países',fontsize=15)
plt.xticks(rótulos2,fontsize=13,rotation=40)
plt.title('Frequência de países',fontsize=20)
plt.show()
